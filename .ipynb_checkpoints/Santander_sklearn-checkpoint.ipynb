# %%
from __future__ import division

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import xgboost as xgb
from sklearn.cross_validation import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score
from sklearn.pipeline import Pipeline
from sklearn.svm import OneClassSVM
import pickle

# %%
# load the data
df_train = pd.read_csv('train.csv/train.csv')
df_test = pd.read_csv('test.csv/test.csv')

#load the pickle where extra computer features are stored
my_features = pickle.load(open("sums.pickle", "rb"))

# %%
feature_to_clean = ['ind_var2_0', 'ind_var2', 'ind_var27_0', 'ind_var28_0', 'ind_var28', 'ind_var27', 'ind_var41', 'ind_var46_0', 'ind_var46', 'num_var27_0', 'num_var28_0', 'num_var28', 'num_var27', 'num_var41', 'num_var46_0', 'num_var46', 'saldo_var28', 'saldo_var27', 'saldo_var41', 'saldo_var46', 'imp_amort_var18_hace3', 'imp_amort_var34_hace3', 'imp_reemb_var13_hace3', 'imp_reemb_var33_hace3', 'imp_trasp_var17_out_hace3', 'imp_trasp_var33_out_hace3', 'num_var2_0_ult1', 'num_var2_ult1', 'num_reemb_var13_hace3', 'num_reemb_var33_hace3', 'num_trasp_var17_out_hace3', 'num_trasp_var33_out_hace3', 'saldo_var2_ult1', 'saldo_medio_var13_medio_hace3',
                   'ind_var29_0', 'ind_var29', 'ind_var13_medio', 'ind_var18', 'ind_var26', 
                     'ind_var25', 'ind_var32', 'ind_var34', 'ind_var37', 'ind_var39', 'num_var29_0', 
                     'num_var29', 'num_var13_medio', 'num_var18', 'num_var26', 'num_var25', 'num_var32', 
                     'num_var34', 'num_var37', 'num_var39', 'saldo_var29', 'saldo_medio_var13_medio_ult1', 
                     'delta_num_reemb_var13_1y3', 'delta_num_reemb_var17_1y3', 'delta_num_reemb_var33_1y3', 
                     'delta_num_trasp_var17_in_1y3', 'delta_num_trasp_var17_out_1y3', 
                     'delta_num_trasp_var33_in_1y3', 'delta_num_trasp_var33_out_1y3',
                   'delta_imp_reemb_var33_1y3',  'imp_reemb_var17_hace3', 'imp_reemb_var33_ult1', 'imp_trasp_var17_in_hace3', 'num_reemb_var17_hace3', 'num_reemb_var33_ult1', 'num_trasp_var17_in_hace3']



df_train.drop(feature_to_clean, axis=1, inplace=True)
df_test.drop(feature_to_clean, axis=1, inplace=True)

# %% [markdown]
# ## Add Sum of 0's

# %%
df_train['sum_of_0'] = my_features['sum_of_0']

# %%
#prepare data for model
y_train = df_train['TARGET'].values
X_train = df_train.drop(['ID','TARGET'], axis=1).values

# %%
id_test = df_test['ID']
X_test = df_test.drop(['ID'], axis=1).values

# %%
# classifier
clf = xgb.XGBClassifier(missing=np.nan, max_depth=5, n_estimators=350, 
                        learning_rate=0.03, nthread=4, subsample=0.95, 
                        colsample_bytree=0.85, seed=4242)

# %%
X_fit, X_eval, y_fit, y_eval= train_test_split(X_train, y_train, test_size=0.3)

# %%
# fitting
clf.fit(X_train, y_train, early_stopping_rounds=20, 
        eval_metric="auc", eval_set=[(X_eval, y_eval)])
# Out:
# Will train until validation_0 error hasn't decreased in 20 rounds.
# [0]	validation_0-auc:0.760614
# [1]	validation_0-auc:0.776214
# [2]	validation_0-auc:0.802037
# [3]	validation_0-auc:0.789661
# [4]	validation_0-auc:0.791377
# [5]	validation_0-auc:0.795666
# [6]	validation_0-auc:0.801506
# [7]	validation_0-auc:0.805580
# [8]	validation_0-auc:0.800317
# [9]	validation_0-auc:0.799445
# [10]	validation_0-auc:0.801956
# [11]	validation_0-auc:0.800035
# [12]	validation_0-auc:0.802227
# [13]	validation_0-auc:0.799606
# [14]	validation_0-auc:0.802611
# [15]	validation_0-auc:0.804760
# [16]	validation_0-auc:0.803396
# [17]	validation_0-auc:0.805681
# [18]	validation_0-auc:0.807264
# [19]	validation_0-auc:0.804662
# [20]	validation_0-auc:0.806094
# [21]	validation_0-auc:0.807305
# [22]	validation_0-auc:0.808805
# [23]	validation_0-auc:0.809911
# [24]	validation_0-auc:0.811318
# [25]	validation_0-auc:0.812796
# [26]	validation_0-auc:0.814023
# [27]	validation_0-auc:0.815543
# [28]	validation_0-auc:0.816507
# [29]	validation_0-auc:0.818148
# [30]	validation_0-auc:0.815890
# [31]	validation_0-auc:0.816682
# [32]	validation_0-auc:0.817536
# [33]	validation_0-auc:0.819278
# [34]	validation_0-auc:0.819914
# [35]	validation_0-auc:0.821404
# [36]	validation_0-auc:0.820984
# [37]	validation_0-auc:0.822975
# [38]	validation_0-auc:0.824052
# [39]	validation_0-auc:0.824663
# [40]	validation_0-auc:0.825394
# [41]	validation_0-auc:0.825419
# [42]	validation_0-auc:0.825339
# [43]	validation_0-auc:0.822965
# [44]	validation_0-auc:0.823867
# [45]	validation_0-auc:0.825083
# [46]	validation_0-auc:0.826680
# [47]	validation_0-auc:0.827077
# [48]	validation_0-auc:0.827790
# [49]	validation_0-auc:0.828371
# [50]	validation_0-auc:0.829375
# [51]	validation_0-auc:0.829868
# [52]	validation_0-auc:0.830165
# [53]	validation_0-auc:0.830670
# [54]	validation_0-auc:0.830730
# [55]	validation_0-auc:0.831482
# [56]	validation_0-auc:0.832018
# [57]	validation_0-auc:0.832791
# [58]	validation_0-auc:0.832626
# [59]	validation_0-auc:0.833199
# [60]	validation_0-auc:0.834077
# [61]	validation_0-auc:0.834419
# [62]	validation_0-auc:0.835301
# [63]	validation_0-auc:0.835726
# [64]	validation_0-auc:0.836183
# [65]	validation_0-auc:0.836117
# [66]	validation_0-auc:0.836730
# [67]	validation_0-auc:0.837407
# [68]	validation_0-auc:0.837773
# [69]	validation_0-auc:0.838003
# [70]	validation_0-auc:0.838597
# [71]	validation_0-auc:0.839368
# [72]	validation_0-auc:0.839975
# [73]	validation_0-auc:0.840256
# [74]	validation_0-auc:0.840809
# [75]	validation_0-auc:0.841013
# [76]	validation_0-auc:0.841281
# [77]	validation_0-auc:0.841638
# [78]	validation_0-auc:0.842077
# [79]	validation_0-auc:0.842014
# [80]	validation_0-auc:0.842293
# [81]	validation_0-auc:0.842205
# [82]	validation_0-auc:0.842281
# [83]	validation_0-auc:0.841872
# [84]	validation_0-auc:0.842162
# [85]	validation_0-auc:0.842262
# [86]	validation_0-auc:0.842615
# [87]	validation_0-auc:0.842768
# [88]	validation_0-auc:0.843221
# [89]	validation_0-auc:0.843761
# [90]	validation_0-auc:0.844196
# [91]	validation_0-auc:0.844368
# [92]	validation_0-auc:0.844683
# [93]	validation_0-auc:0.844841
# [94]	validation_0-auc:0.845382
# [95]	validation_0-auc:0.845698
# [96]	validation_0-auc:0.846124
# [97]	validation_0-auc:0.846234
# [98]	validation_0-auc:0.846397
# [99]	validation_0-auc:0.846656
# [100]	validation_0-auc:0.846809
# [101]	validation_0-auc:0.847158
# [102]	validation_0-auc:0.847359
# [103]	validation_0-auc:0.847724
# [104]	validation_0-auc:0.848085
# [105]	validation_0-auc:0.848704
# [106]	validation_0-auc:0.849046
# [107]	validation_0-auc:0.849446
# [108]	validation_0-auc:0.849686
# [109]	validation_0-auc:0.850008
# [110]	validation_0-auc:0.850113
# [111]	validation_0-auc:0.850603
# [112]	validation_0-auc:0.850889
# [113]	validation_0-auc:0.851144
# [114]	validation_0-auc:0.851342
# [115]	validation_0-auc:0.851464
# [116]	validation_0-auc:0.851878
# [117]	validation_0-auc:0.852034
# [118]	validation_0-auc:0.852315
# [119]	validation_0-auc:0.852475
# [120]	validation_0-auc:0.852879
# [121]	validation_0-auc:0.853293
# [122]	validation_0-auc:0.853676
# [123]	validation_0-auc:0.853974
# [124]	validation_0-auc:0.854266
# [125]	validation_0-auc:0.854457
# [126]	validation_0-auc:0.854632
# [127]	validation_0-auc:0.855021
# [128]	validation_0-auc:0.855105
# [129]	validation_0-auc:0.855249
# [130]	validation_0-auc:0.855453
# [131]	validation_0-auc:0.855668
# [132]	validation_0-auc:0.855812
# [133]	validation_0-auc:0.855978
# [134]	validation_0-auc:0.856319
# [135]	validation_0-auc:0.856475
# [136]	validation_0-auc:0.856587
# [137]	validation_0-auc:0.856742
# [138]	validation_0-auc:0.856975
# [139]	validation_0-auc:0.857108
# [140]	validation_0-auc:0.857201
# [141]	validation_0-auc:0.857381
# [142]	validation_0-auc:0.857629
# [143]	validation_0-auc:0.857893
# [144]	validation_0-auc:0.858021
# [145]	validation_0-auc:0.858246
# [146]	validation_0-auc:0.858397
# [147]	validation_0-auc:0.858570
# [148]	validation_0-auc:0.858582
# [149]	validation_0-auc:0.858662
# [150]	validation_0-auc:0.858755
# [151]	validation_0-auc:0.858891
# [152]	validation_0-auc:0.859034
# [153]	validation_0-auc:0.859111
# [154]	validation_0-auc:0.859339
# [155]	validation_0-auc:0.859498
# [156]	validation_0-auc:0.859743
# [157]	validation_0-auc:0.859885
# [158]	validation_0-auc:0.860061
# [159]	validation_0-auc:0.860110
# [160]	validation_0-auc:0.860363
# [161]	validation_0-auc:0.860607
# [162]	validation_0-auc:0.860682
# [163]	validation_0-auc:0.860737
# [164]	validation_0-auc:0.860846
# [165]	validation_0-auc:0.861043
# [166]	validation_0-auc:0.861237
# [167]	validation_0-auc:0.861407
# [168]	validation_0-auc:0.861558
# [169]	validation_0-auc:0.861728
# [170]	validation_0-auc:0.861937
# [171]	validation_0-auc:0.862154
# [172]	validation_0-auc:0.862161
# [173]	validation_0-auc:0.862392
# [174]	validation_0-auc:0.862481
# [175]	validation_0-auc:0.862599
# [176]	validation_0-auc:0.862783
# [177]	validation_0-auc:0.862919
# [178]	validation_0-auc:0.863132
# [179]	validation_0-auc:0.863364
# [180]	validation_0-auc:0.863313
# [181]	validation_0-auc:0.863341
# [182]	validation_0-auc:0.863513
# [183]	validation_0-auc:0.863639
# [184]	validation_0-auc:0.863762
# [185]	validation_0-auc:0.863942
# [186]	validation_0-auc:0.864128
# [187]	validation_0-auc:0.864341
# [188]	validation_0-auc:0.864522
# [189]	validation_0-auc:0.864683
# [190]	validation_0-auc:0.864832
# [191]	validation_0-auc:0.864867
# [192]	validation_0-auc:0.864845
# [193]	validation_0-auc:0.865001
# [194]	validation_0-auc:0.865066
# [195]	validation_0-auc:0.865083
# [196]	validation_0-auc:0.865320
# [197]	validation_0-auc:0.865388
# [198]	validation_0-auc:0.865404
# [199]	validation_0-auc:0.865457
# [200]	validation_0-auc:0.865659
# [201]	validation_0-auc:0.865735
# [202]	validation_0-auc:0.865864
# [203]	validation_0-auc:0.865800
# [204]	validation_0-auc:0.865919
# [205]	validation_0-auc:0.866152
# [206]	validation_0-auc:0.866248
# [207]	validation_0-auc:0.866360
# [208]	validation_0-auc:0.866496
# [209]	validation_0-auc:0.866596
# [210]	validation_0-auc:0.866771
# [211]	validation_0-auc:0.866792
# [212]	validation_0-auc:0.867138
# [213]	validation_0-auc:0.867240
# [214]	validation_0-auc:0.867409
# [215]	validation_0-auc:0.867682
# [216]	validation_0-auc:0.867820
# [217]	validation_0-auc:0.867780
# [218]	validation_0-auc:0.867972
# [219]	validation_0-auc:0.868108
# [220]	validation_0-auc:0.868190
# [221]	validation_0-auc:0.868371
# [222]	validation_0-auc:0.868496
# [223]	validation_0-auc:0.868714
# [224]	validation_0-auc:0.868874
# [225]	validation_0-auc:0.868564
# [226]	validation_0-auc:0.868383
# [227]	validation_0-auc:0.868510
# [228]	validation_0-auc:0.868598
# [229]	validation_0-auc:0.868679
# [230]	validation_0-auc:0.868689
# [231]	validation_0-auc:0.868839
# [232]	validation_0-auc:0.869047
# [233]	validation_0-auc:0.869267
# [234]	validation_0-auc:0.869473
# [235]	validation_0-auc:0.869613
# [236]	validation_0-auc:0.869632
# [237]	validation_0-auc:0.869870
# [238]	validation_0-auc:0.870009
# [239]	validation_0-auc:0.869882
# [240]	validation_0-auc:0.869963
# [241]	validation_0-auc:0.870054
# [242]	validation_0-auc:0.870168
# [243]	validation_0-auc:0.870233
# [244]	validation_0-auc:0.870245
# [245]	validation_0-auc:0.870272
# [246]	validation_0-auc:0.870315
# [247]	validation_0-auc:0.870430
# [248]	validation_0-auc:0.870497
# [249]	validation_0-auc:0.870523
# [250]	validation_0-auc:0.870659
# [251]	validation_0-auc:0.870683
# [252]	validation_0-auc:0.870718
# [253]	validation_0-auc:0.870762
# [254]	validation_0-auc:0.870859
# [255]	validation_0-auc:0.871077
# [256]	validation_0-auc:0.871158
# [257]	validation_0-auc:0.871229
# [258]	validation_0-auc:0.871329
# [259]	validation_0-auc:0.871481
# [260]	validation_0-auc:0.871509
# [261]	validation_0-auc:0.871547
# [262]	validation_0-auc:0.871763
# [263]	validation_0-auc:0.871865
# [264]	validation_0-auc:0.871904
# [265]	validation_0-auc:0.872017
# [266]	validation_0-auc:0.872050
# [267]	validation_0-auc:0.872119
# [268]	validation_0-auc:0.872169
# [269]	validation_0-auc:0.872221
# [270]	validation_0-auc:0.872215
# [271]	validation_0-auc:0.872328
# [272]	validation_0-auc:0.872371
# [273]	validation_0-auc:0.872396
# [274]	validation_0-auc:0.872433
# [275]	validation_0-auc:0.872499
# [276]	validation_0-auc:0.872517
# [277]	validation_0-auc:0.872554
# [278]	validation_0-auc:0.872784
# [279]	validation_0-auc:0.872443
# [280]	validation_0-auc:0.872554
# [281]	validation_0-auc:0.872652
# [282]	validation_0-auc:0.872680
# [283]	validation_0-auc:0.872762
# [284]	validation_0-auc:0.872779
# [285]	validation_0-auc:0.872794
# [286]	validation_0-auc:0.872815
# [287]	validation_0-auc:0.872833
# [288]	validation_0-auc:0.872997
# [289]	validation_0-auc:0.873099
# [290]	validation_0-auc:0.873127
# [291]	validation_0-auc:0.873173
# [292]	validation_0-auc:0.873228
# [293]	validation_0-auc:0.873127
# [294]	validation_0-auc:0.873223
# [295]	validation_0-auc:0.873262
# [296]	validation_0-auc:0.873272
# [297]	validation_0-auc:0.873330
# [298]	validation_0-auc:0.873362
# [299]	validation_0-auc:0.873480
# [300]	validation_0-auc:0.873584
# [301]	validation_0-auc:0.873477
# [302]	validation_0-auc:0.873501
# [303]	validation_0-auc:0.873556
# [304]	validation_0-auc:0.873614
# [305]	validation_0-auc:0.873650
# [306]	validation_0-auc:0.873676
# [307]	validation_0-auc:0.873789
# [308]	validation_0-auc:0.873821
# [309]	validation_0-auc:0.873703
# [310]	validation_0-auc:0.873780
# [311]	validation_0-auc:0.873893
# [312]	validation_0-auc:0.873909
# [313]	validation_0-auc:0.873942
# [314]	validation_0-auc:0.873996
# [315]	validation_0-auc:0.874047
# [316]	validation_0-auc:0.873934
# [317]	validation_0-auc:0.874022
# [318]	validation_0-auc:0.874129
# [319]	validation_0-auc:0.874231
# [320]	validation_0-auc:0.874266
# [321]	validation_0-auc:0.874351
# [322]	validation_0-auc:0.874447
# [323]	validation_0-auc:0.874550
# [324]	validation_0-auc:0.874464
# [325]	validation_0-auc:0.874613
# [326]	validation_0-auc:0.874808
# [327]	validation_0-auc:0.874842
# [328]	validation_0-auc:0.874992
# [329]	validation_0-auc:0.875039
# [330]	validation_0-auc:0.875052
# [331]	validation_0-auc:0.875122
# [332]	validation_0-auc:0.875182
# [333]	validation_0-auc:0.875230
# [334]	validation_0-auc:0.875242
# [335]	validation_0-auc:0.875408
# [336]	validation_0-auc:0.875444
# [337]	validation_0-auc:0.875509
# [338]	validation_0-auc:0.875546
# [339]	validation_0-auc:0.875574
# [340]	validation_0-auc:0.875714
# [341]	validation_0-auc:0.875818
# [342]	validation_0-auc:0.875634
# [343]	validation_0-auc:0.875932
# [344]	validation_0-auc:0.875959
# [345]	validation_0-auc:0.875991
# [346]	validation_0-auc:0.876146
# [347]	validation_0-auc:0.876228
# [348]	validation_0-auc:0.876229
# [349]	validation_0-auc:0.876440
# XGBClassifier(base_score=0.5, colsample_bylevel=1, colsample_bytree=0.85,
#        gamma=0, learning_rate=0.03, max_delta_step=0, max_depth=5,
#        min_child_weight=1, missing=None, n_estimators=350, nthread=4,
#        objective='binary:logistic', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=4242, silent=True, subsample=0.95)

# %%
print('Overall AUC:', roc_auc_score(y_train, clf.predict_proba(X_train)[:,1]))
# Out:
# ('Overall AUC:', 0.88249734213757924)

# %%
# predicting
y_pred= clf.predict_proba(X_test)[:,1]

# %%
submission = pd.DataFrame({"ID":id_test, "TARGET":y_pred})
submission.to_csv("submission16.csv", index=False)

# %%
'''
ADDITIONAL FUNCTIONS FOR FEATURE ENGINEERING
==============================================================
import pickle
to_save = {
    "sum_of_0":df_train['sum_of_0']
}
pickle.dump(to_save, open('my_features.pickle','a'))
===============================================================
#NAME: ADD SUM OF 0'S
# select on the features, leaving out the 'TARGET' feature


features = [f for f in df_train.columns if f != 'TARGET' and f!='ID' ]

def calculate_zeros(cols):
    sum_array = [] 
    for value in cols:
        if value == 0:
            sum_array.append(value)
    return len(sum_array)

df_train['sum_of_0'] = df_train[features].apply(calculate_zeros, axis=1)

===============================================================

# remove duplicated columns
remove = []
c = df_train.columns
for i in range(len(c)-1):
    v = df_train[c[i]].values
    for j in range(i+1, len(c)):
        if np.array_equal(v, df_train[c[j]].values):
            remove.append(c[j])

df_train.drop(remove, axis=1, inplace=True)
df_test.drop(remove, axis=1, inplace=True)

================================================================

# remove constant columns
remove = []
for col in df_train.columns:
    if df_train[col].std() == 0:
        remove.append(col)
================================================================

def fix_nationality(nat):
    for value in nat:
        if value == -999999:
            return 2
        else:
            return value

df_train['var3'] = df_train[['var3']].apply(fix_nationality, axis=1)


'''
# Out:
# '\nADDITIONAL FUNCTIONS FOR FEATURE ENGINEERING\n==============================================================\nimport pickle\nto_save = {\n    "sum_of_0":df_train[\'sum_of_0\']\n}\npickle.dump(to_save, open(\'my_features.pickle\',\'a\'))\n===============================================================\n#NAME: ADD SUM OF 0\'S\n# select on the features, leaving out the \'TARGET\' feature\n\n\nfeatures = [f for f in df_train.columns if f != \'TARGET\' and f!=\'ID\' ]\n\ndef calculate_zeros(cols):\n    sum_array = [] \n    for value in cols:\n        if value == 0:\n            sum_array.append(value)\n    return len(sum_array)\n\ndf_train[\'sum_of_0\'] = df_train[features].apply(calculate_zeros, axis=1)\n\n===============================================================\n\n# remove duplicated columns\nremove = []\nc = df_train.columns\nfor i in range(len(c)-1):\n    v = df_train[c[i]].values\n    for j in range(i+1, len(c)):\n        if np.array_equal(v, df_train[c[j]].values):\n            remove.append(c[j])\n\ndf_train.drop(remove, axis=1, inplace=True)\ndf_test.drop(remove, axis=1, inplace=True)\n\n================================================================\n\n# remove constant columns\nremove = []\nfor col in df_train.columns:\n    if df_train[col].std() == 0:\n        remove.append(col)\n================================================================\n\ndef fix_nationality(nat):\n    for value in nat:\n        if value == -999999:\n            return 2\n        else:\n            return value\n\ndf_train[\'var3\'] = df_train[[\'var3\']].apply(fix_nationality, axis=1)\n\n\n'
