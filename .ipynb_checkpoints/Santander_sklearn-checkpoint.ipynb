# %%
from __future__ import division

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import xgboost as xgb
from sklearn.cross_validation import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score
from sklearn.pipeline import Pipeline
from sklearn.svm import OneClassSVM
import pickle

# %%
# load the data
df_train = pd.read_csv('train.csv/train.csv')
df_test = pd.read_csv('test.csv/test.csv')

#load the pickle where extra computer features are stored
my_features = pickle.load(open("sums.pickle", "rb"))

# %%
feature_to_clean = ['ind_var2_0', 'ind_var2', 'ind_var27_0', 'ind_var28_0', 'ind_var28', 'ind_var27', 'ind_var41', 'ind_var46_0', 'ind_var46', 'num_var27_0', 'num_var28_0', 'num_var28', 'num_var27', 'num_var41', 'num_var46_0', 'num_var46', 'saldo_var28', 'saldo_var27', 'saldo_var41', 'saldo_var46', 'imp_amort_var18_hace3', 'imp_amort_var34_hace3', 'imp_reemb_var13_hace3', 'imp_reemb_var33_hace3', 'imp_trasp_var17_out_hace3', 'imp_trasp_var33_out_hace3', 'num_var2_0_ult1', 'num_var2_ult1', 'num_reemb_var13_hace3', 'num_reemb_var33_hace3', 'num_trasp_var17_out_hace3', 'num_trasp_var33_out_hace3', 'saldo_var2_ult1', 'saldo_medio_var13_medio_hace3',
                   'ind_var29_0', 'ind_var29', 'ind_var13_medio', 'ind_var18', 'ind_var26', 
                     'ind_var25', 'ind_var32', 'ind_var34', 'ind_var37', 'ind_var39', 'num_var29_0', 
                     'num_var29', 'num_var13_medio', 'num_var18', 'num_var26', 'num_var25', 'num_var32', 
                     'num_var34', 'num_var37', 'num_var39', 'saldo_var29', 'saldo_medio_var13_medio_ult1', 
                     'delta_num_reemb_var13_1y3', 'delta_num_reemb_var17_1y3', 'delta_num_reemb_var33_1y3', 
                     'delta_num_trasp_var17_in_1y3', 'delta_num_trasp_var17_out_1y3', 
                     'delta_num_trasp_var33_in_1y3', 'delta_num_trasp_var33_out_1y3',
                   'delta_imp_reemb_var33_1y3',  'imp_reemb_var17_hace3', 'imp_reemb_var33_ult1', 'imp_trasp_var17_in_hace3', 'num_reemb_var17_hace3', 'num_reemb_var33_ult1', 'num_trasp_var17_in_hace3']



df_train.drop(feature_to_clean, axis=1, inplace=True)
df_test.drop(feature_to_clean, axis=1, inplace=True)

# %% [markdown]
# ## Add binary features for each value
# 1. here I want to add additional columns for each value in each feature.
# 2. For now I will just try add add "1" for where "0" is found

# %%
features_extraction = ['num_var13_corto', 'num_var13_corto_0', 'num_meses_var12_ult3', 'num_meses_var13_corto_ult3',
                      'num_meses_var39_vig_ult3', 'num_meses_var5_ult3','num_var24_0','num_var12','var36',
                      'num_var5','num_var5_0','num_var12_0','num_var13','num_var13_0','num_var42','num_var4',
                      'num_var42_0','num_var30','num_var39_0','num_var41_0']

# %%
#add a binary new feature for each category in each of the features extraction

def add_binary_features(cols,cat):
    for value in cols:
        if value == cat:
            return 1
        else:
            return 0 

tracker = 1
for f in features_extraction:
    categories = np.intersect1d( df_test[f] , df_train[f])
    #train_categories = df_train[f].unique()
    for cat in categories:
        df_train[f+"_"+str(cat)] = df_train[[f]].apply(add_binary_features, args=(cat,), axis=1)
        df_test[f+"_"+str(cat)] = df_test[[f]].apply(add_binary_features, args=(cat,), axis=1)
    
    print "Done with " + str(tracker)
    
    tracker+=1
# Out:
# Done with 1
# Done with 2
# Done with 3
# Done with 4
# Done with 5
# Done with 6
# Done with 7
# Done with 8
# Done with 9
# Done with 10
# Done with 11
# Done with 12
# Done with 13
# Done with 14
# Done with 15
# Done with 16
# Done with 17
# Done with 18
# Done with 19
# Done with 20

# %%
# TODO: drop the features
df_train.drop(features_extraction, axis=1, inplace=True)
df_test.drop(features_extraction, axis=1, inplace=True)

# %% [markdown]
# ## Add Sum of 0's

# %%
features = [f for f in df_train.columns if f != 'TARGET' and f!='ID' ]
#df_train['sum_of_0'] = my_features['sum_of_0']
def calculate_zeros(cols):
    sum_array = [] 
    for value in cols:
        if value == 0:
            sum_array.append(value)
    return len(sum_array)

df_train['sum_of_0'] = df_train[features].apply(calculate_zeros, axis=1)
df_test['sum_of_0'] = df_test[features].apply(calculate_zeros, axis=1)

# %%
#prepare data for model
y_train = df_train['TARGET'].values
X_train = df_train.drop(['ID','TARGET'], axis=1).values

# %%
id_test = df_test['ID']
X_test = df_test.drop(['ID'], axis=1).values

# %%
# classifier
clf = xgb.XGBClassifier(missing=np.nan, max_depth=5, n_estimators=350, 
                        learning_rate=0.03, nthread=4, subsample=0.95, 
                        colsample_bytree=0.85, seed=4242)

# %%
X_fit, X_eval, y_fit, y_eval= train_test_split(X_train, y_train, test_size=0.3)

# %%
# fitting
clf.fit(X_train, y_train, early_stopping_rounds=20, 
        eval_metric="auc", eval_set=[(X_eval, y_eval)])
# Out:
# Will train until validation_0 error hasn't decreased in 20 rounds.
# [0]	validation_0-auc:0.803974
# [1]	validation_0-auc:0.814977
# [2]	validation_0-auc:0.816710
# [3]	validation_0-auc:0.818565
# [4]	validation_0-auc:0.821697
# [5]	validation_0-auc:0.819563
# [6]	validation_0-auc:0.805274
# [7]	validation_0-auc:0.809774
# [8]	validation_0-auc:0.809514
# [9]	validation_0-auc:0.811717
# [10]	validation_0-auc:0.813498
# [11]	validation_0-auc:0.814644
# [12]	validation_0-auc:0.816544
# [13]	validation_0-auc:0.820582
# [14]	validation_0-auc:0.822175
# [15]	validation_0-auc:0.821346
# [16]	validation_0-auc:0.822476
# [17]	validation_0-auc:0.814686
# [18]	validation_0-auc:0.815300
# [19]	validation_0-auc:0.816239
# [20]	validation_0-auc:0.816465
# [21]	validation_0-auc:0.817908
# [22]	validation_0-auc:0.818835
# [23]	validation_0-auc:0.813721
# [24]	validation_0-auc:0.813022
# [25]	validation_0-auc:0.814791
# [26]	validation_0-auc:0.815599
# [27]	validation_0-auc:0.816502
# [28]	validation_0-auc:0.816560
# [29]	validation_0-auc:0.816807
# [30]	validation_0-auc:0.818394
# [31]	validation_0-auc:0.819135
# [32]	validation_0-auc:0.819505
# [33]	validation_0-auc:0.821497
# [34]	validation_0-auc:0.821993
# [35]	validation_0-auc:0.822720
# [36]	validation_0-auc:0.822987
# [37]	validation_0-auc:0.824191
# [38]	validation_0-auc:0.823030
# [39]	validation_0-auc:0.824170
# [40]	validation_0-auc:0.825243
# [41]	validation_0-auc:0.825817
# [42]	validation_0-auc:0.825843
# [43]	validation_0-auc:0.823709
# [44]	validation_0-auc:0.824052
# [45]	validation_0-auc:0.824738
# [46]	validation_0-auc:0.825868
# [47]	validation_0-auc:0.826197
# [48]	validation_0-auc:0.823375
# [49]	validation_0-auc:0.824533
# [50]	validation_0-auc:0.825642
# [51]	validation_0-auc:0.827023
# [52]	validation_0-auc:0.827537
# [53]	validation_0-auc:0.827533
# [54]	validation_0-auc:0.828072
# [55]	validation_0-auc:0.829018
# [56]	validation_0-auc:0.829189
# [57]	validation_0-auc:0.829459
# [58]	validation_0-auc:0.830310
# [59]	validation_0-auc:0.830663
# [60]	validation_0-auc:0.831164
# [61]	validation_0-auc:0.831612
# [62]	validation_0-auc:0.832311
# [63]	validation_0-auc:0.833827
# [64]	validation_0-auc:0.834267
# [65]	validation_0-auc:0.834469
# [66]	validation_0-auc:0.834802
# [67]	validation_0-auc:0.835351
# [68]	validation_0-auc:0.835307
# [69]	validation_0-auc:0.835697
# [70]	validation_0-auc:0.835863
# [71]	validation_0-auc:0.836489
# [72]	validation_0-auc:0.836610
# [73]	validation_0-auc:0.836811
# [74]	validation_0-auc:0.836951
# [75]	validation_0-auc:0.837604
# [76]	validation_0-auc:0.837753
# [77]	validation_0-auc:0.838191
# [78]	validation_0-auc:0.838440
# [79]	validation_0-auc:0.837447
# [80]	validation_0-auc:0.837825
# [81]	validation_0-auc:0.838448
# [82]	validation_0-auc:0.838547
# [83]	validation_0-auc:0.839260
# [84]	validation_0-auc:0.839392
# [85]	validation_0-auc:0.839727
# [86]	validation_0-auc:0.840081
# [87]	validation_0-auc:0.840387
# [88]	validation_0-auc:0.840570
# [89]	validation_0-auc:0.840727
# [90]	validation_0-auc:0.841270
# [91]	validation_0-auc:0.841645
# [92]	validation_0-auc:0.842044
# [93]	validation_0-auc:0.842408
# [94]	validation_0-auc:0.842770
# [95]	validation_0-auc:0.843317
# [96]	validation_0-auc:0.843471
# [97]	validation_0-auc:0.843750
# [98]	validation_0-auc:0.843920
# [99]	validation_0-auc:0.844178
# [100]	validation_0-auc:0.844711
# [101]	validation_0-auc:0.844920
# [102]	validation_0-auc:0.845293
# [103]	validation_0-auc:0.845511
# [104]	validation_0-auc:0.845841
# [105]	validation_0-auc:0.846278
# [106]	validation_0-auc:0.846675
# [107]	validation_0-auc:0.847103
# [108]	validation_0-auc:0.847481
# [109]	validation_0-auc:0.847476
# [110]	validation_0-auc:0.848017
# [111]	validation_0-auc:0.848160
# [112]	validation_0-auc:0.848382
# [113]	validation_0-auc:0.848621
# [114]	validation_0-auc:0.848771
# [115]	validation_0-auc:0.849135
# [116]	validation_0-auc:0.849330
# [117]	validation_0-auc:0.849547
# [118]	validation_0-auc:0.849699
# [119]	validation_0-auc:0.850118
# [120]	validation_0-auc:0.850494
# [121]	validation_0-auc:0.850713
# [122]	validation_0-auc:0.851182
# [123]	validation_0-auc:0.851433
# [124]	validation_0-auc:0.851709
# [125]	validation_0-auc:0.852000
# [126]	validation_0-auc:0.852225
# [127]	validation_0-auc:0.852286
# [128]	validation_0-auc:0.852465
# [129]	validation_0-auc:0.852393
# [130]	validation_0-auc:0.852462
# [131]	validation_0-auc:0.852786
# [132]	validation_0-auc:0.853033
# [133]	validation_0-auc:0.853270
# [134]	validation_0-auc:0.853470
# [135]	validation_0-auc:0.853873
# [136]	validation_0-auc:0.854097
# [137]	validation_0-auc:0.854210
# [138]	validation_0-auc:0.854434
# [139]	validation_0-auc:0.854605
# [140]	validation_0-auc:0.854757
# [141]	validation_0-auc:0.855043
# [142]	validation_0-auc:0.855185
# [143]	validation_0-auc:0.855477
# [144]	validation_0-auc:0.855498
# [145]	validation_0-auc:0.855828
# [146]	validation_0-auc:0.856014
# [147]	validation_0-auc:0.856218
# [148]	validation_0-auc:0.856377
# [149]	validation_0-auc:0.856589
# [150]	validation_0-auc:0.856813
# [151]	validation_0-auc:0.856987
# [152]	validation_0-auc:0.857141
# [153]	validation_0-auc:0.857315
# [154]	validation_0-auc:0.857470
# [155]	validation_0-auc:0.857690
# [156]	validation_0-auc:0.857935
# [157]	validation_0-auc:0.858126
# [158]	validation_0-auc:0.858322
# [159]	validation_0-auc:0.858620
# [160]	validation_0-auc:0.858760
# [161]	validation_0-auc:0.858896
# [162]	validation_0-auc:0.859053
# [163]	validation_0-auc:0.859225
# [164]	validation_0-auc:0.859232
# [165]	validation_0-auc:0.859466
# [166]	validation_0-auc:0.859583
# [167]	validation_0-auc:0.859829
# [168]	validation_0-auc:0.859931
# [169]	validation_0-auc:0.860058
# [170]	validation_0-auc:0.860305
# [171]	validation_0-auc:0.860263
# [172]	validation_0-auc:0.860415
# [173]	validation_0-auc:0.860609
# [174]	validation_0-auc:0.860788
# [175]	validation_0-auc:0.860904
# [176]	validation_0-auc:0.860980
# [177]	validation_0-auc:0.861159
# [178]	validation_0-auc:0.861510
# [179]	validation_0-auc:0.861520
# [180]	validation_0-auc:0.861624
# [181]	validation_0-auc:0.861827
# [182]	validation_0-auc:0.861961
# [183]	validation_0-auc:0.862079
# [184]	validation_0-auc:0.862243
# [185]	validation_0-auc:0.862345
# [186]	validation_0-auc:0.862421
# [187]	validation_0-auc:0.862437
# [188]	validation_0-auc:0.862581
# [189]	validation_0-auc:0.862732
# [190]	validation_0-auc:0.862807
# [191]	validation_0-auc:0.862724
# [192]	validation_0-auc:0.862625
# [193]	validation_0-auc:0.862723
# [194]	validation_0-auc:0.862573
# [195]	validation_0-auc:0.862652
# [196]	validation_0-auc:0.862720
# [197]	validation_0-auc:0.862872
# [198]	validation_0-auc:0.862912
# [199]	validation_0-auc:0.863053
# [200]	validation_0-auc:0.863145
# [201]	validation_0-auc:0.863352
# [202]	validation_0-auc:0.863483
# [203]	validation_0-auc:0.863339
# [204]	validation_0-auc:0.863480
# [205]	validation_0-auc:0.863603
# [206]	validation_0-auc:0.863716
# [207]	validation_0-auc:0.863866
# [208]	validation_0-auc:0.863705
# [209]	validation_0-auc:0.863910
# [210]	validation_0-auc:0.864152
# [211]	validation_0-auc:0.864169
# [212]	validation_0-auc:0.864250
# [213]	validation_0-auc:0.864289
# [214]	validation_0-auc:0.864481
# [215]	validation_0-auc:0.864706
# [216]	validation_0-auc:0.864897
# [217]	validation_0-auc:0.865009
# [218]	validation_0-auc:0.865051
# [219]	validation_0-auc:0.865054
# [220]	validation_0-auc:0.865119
# [221]	validation_0-auc:0.865260
# [222]	validation_0-auc:0.865133
# [223]	validation_0-auc:0.864864
# [224]	validation_0-auc:0.864985
# [225]	validation_0-auc:0.865068
# [226]	validation_0-auc:0.865158
# [227]	validation_0-auc:0.865215
# [228]	validation_0-auc:0.865208
# [229]	validation_0-auc:0.865422
# [230]	validation_0-auc:0.865455
# [231]	validation_0-auc:0.865516
# [232]	validation_0-auc:0.865635
# [233]	validation_0-auc:0.865684
# [234]	validation_0-auc:0.865755
# [235]	validation_0-auc:0.865832
# [236]	validation_0-auc:0.865928
# [237]	validation_0-auc:0.866073
# [238]	validation_0-auc:0.866177
# [239]	validation_0-auc:0.866232
# [240]	validation_0-auc:0.866263
# [241]	validation_0-auc:0.866379
# [242]	validation_0-auc:0.866495
# [243]	validation_0-auc:0.866517
# [244]	validation_0-auc:0.866590
# [245]	validation_0-auc:0.866711
# [246]	validation_0-auc:0.866751
# [247]	validation_0-auc:0.866843
# [248]	validation_0-auc:0.866969
# [249]	validation_0-auc:0.867095
# [250]	validation_0-auc:0.866907
# [251]	validation_0-auc:0.866972
# [252]	validation_0-auc:0.867016
# [253]	validation_0-auc:0.867032
# [254]	validation_0-auc:0.867072
# [255]	validation_0-auc:0.867209
# [256]	validation_0-auc:0.867302
# [257]	validation_0-auc:0.867409
# [258]	validation_0-auc:0.867452
# [259]	validation_0-auc:0.867372
# [260]	validation_0-auc:0.867401
# [261]	validation_0-auc:0.867287
# [262]	validation_0-auc:0.867313
# [263]	validation_0-auc:0.867373
# [264]	validation_0-auc:0.867597
# [265]	validation_0-auc:0.867677
# [266]	validation_0-auc:0.867853
# [267]	validation_0-auc:0.867891
# [268]	validation_0-auc:0.867939
# [269]	validation_0-auc:0.868009
# [270]	validation_0-auc:0.867905
# [271]	validation_0-auc:0.867779
# [272]	validation_0-auc:0.867891
# [273]	validation_0-auc:0.867919
# [274]	validation_0-auc:0.867985
# [275]	validation_0-auc:0.868048
# [276]	validation_0-auc:0.868108
# [277]	validation_0-auc:0.868159
# [278]	validation_0-auc:0.868074
# [279]	validation_0-auc:0.868230
# [280]	validation_0-auc:0.868290
# [281]	validation_0-auc:0.868349
# [282]	validation_0-auc:0.868484
# [283]	validation_0-auc:0.868497
# [284]	validation_0-auc:0.868541
# [285]	validation_0-auc:0.868696
# [286]	validation_0-auc:0.868739
# [287]	validation_0-auc:0.868795
# [288]	validation_0-auc:0.868841
# [289]	validation_0-auc:0.868953
# [290]	validation_0-auc:0.868985
# [291]	validation_0-auc:0.869218
# [292]	validation_0-auc:0.869055
# [293]	validation_0-auc:0.869158
# [294]	validation_0-auc:0.869282
# [295]	validation_0-auc:0.869402
# [296]	validation_0-auc:0.869492
# [297]	validation_0-auc:0.869612
# [298]	validation_0-auc:0.869630
# [299]	validation_0-auc:0.869666
# [300]	validation_0-auc:0.869703
# [301]	validation_0-auc:0.869764
# [302]	validation_0-auc:0.869798
# [303]	validation_0-auc:0.869838
# [304]	validation_0-auc:0.869860
# [305]	validation_0-auc:0.869885
# [306]	validation_0-auc:0.869933
# [307]	validation_0-auc:0.869986
# [308]	validation_0-auc:0.870120
# [309]	validation_0-auc:0.869951
# [310]	validation_0-auc:0.869940
# [311]	validation_0-auc:0.870000
# [312]	validation_0-auc:0.870093
# [313]	validation_0-auc:0.870140
# [314]	validation_0-auc:0.870222
# [315]	validation_0-auc:0.870377
# [316]	validation_0-auc:0.870439
# [317]	validation_0-auc:0.870369
# [318]	validation_0-auc:0.870408
# [319]	validation_0-auc:0.870497
# [320]	validation_0-auc:0.870581
# [321]	validation_0-auc:0.870711
# [322]	validation_0-auc:0.870726
# [323]	validation_0-auc:0.870882
# [324]	validation_0-auc:0.870984
# [325]	validation_0-auc:0.871022
# [326]	validation_0-auc:0.871044
# [327]	validation_0-auc:0.871098
# [328]	validation_0-auc:0.871126
# [329]	validation_0-auc:0.871197
# [330]	validation_0-auc:0.871118
# [331]	validation_0-auc:0.871253
# [332]	validation_0-auc:0.871300
# [333]	validation_0-auc:0.871373
# [334]	validation_0-auc:0.871449
# [335]	validation_0-auc:0.871480
# [336]	validation_0-auc:0.871243
# [337]	validation_0-auc:0.871292
# [338]	validation_0-auc:0.871355
# [339]	validation_0-auc:0.871391
# [340]	validation_0-auc:0.871605
# [341]	validation_0-auc:0.871510
# [342]	validation_0-auc:0.871583
# [343]	validation_0-auc:0.871740
# [344]	validation_0-auc:0.871780
# [345]	validation_0-auc:0.871800
# [346]	validation_0-auc:0.871926
# [347]	validation_0-auc:0.872106
# [348]	validation_0-auc:0.872177
# [349]	validation_0-auc:0.872208
# [350]	validation_0-auc:0.872308
# [351]	validation_0-auc:0.872335
# [352]	validation_0-auc:0.872375
# [353]	validation_0-auc:0.872468
# [354]	validation_0-auc:0.872562
# [355]	validation_0-auc:0.872584
# [356]	validation_0-auc:0.872543
# [357]	validation_0-auc:0.872620
# [358]	validation_0-auc:0.872535
# [359]	validation_0-auc:0.872606
# [360]	validation_0-auc:0.872663
# [361]	validation_0-auc:0.872715
# [362]	validation_0-auc:0.872837
# [363]	validation_0-auc:0.872944
# [364]	validation_0-auc:0.872967
# [365]	validation_0-auc:0.872979
# [366]	validation_0-auc:0.873028
# [367]	validation_0-auc:0.873160
# [368]	validation_0-auc:0.873316
# [369]	validation_0-auc:0.873335
# XGBClassifier(base_score=0.5, colsample_bylevel=1, colsample_bytree=0.85,
#        gamma=0, learning_rate=0.03, max_delta_step=0, max_depth=5,
#        min_child_weight=1, missing=None, n_estimators=370, nthread=4,
#        objective='binary:logistic', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=4242, silent=True, subsample=0.95)

# %%
print('Overall AUC:', roc_auc_score(y_train, clf.predict_proba(X_train)[:,1]))
# Out:
# ('Overall AUC:', 0.88393595821030879)

# %%
# predicting
y_pred= clf.predict_proba(X_test)[:,1]

# %%
submission = pd.DataFrame({"ID":id_test, "TARGET":y_pred})
submission.to_csv("submission41.csv", index=False)

# %%
'''
ADDITIONAL FUNCTIONS FOR FEATURE ENGINEERING
==============================================================
import pickle
to_save = {
    "sum_of_0":df_train['sum_of_0']
}
pickle.dump(to_save, open('my_features.pickle','a'))
===============================================================
#NAME: ADD SUM OF 0'S
# select on the features, leaving out the 'TARGET' feature


features = [f for f in df_train.columns if f != 'TARGET' and f!='ID' ]

def calculate_zeros(cols):
    sum_array = [] 
    for value in cols:
        if value == 0:
            sum_array.append(value)
    return len(sum_array)

df_train['sum_of_0'] = df_train[features].apply(calculate_zeros, axis=1)

===============================================================

# remove duplicated columns
remove = []
c = df_train.columns
for i in range(len(c)-1):
    v = df_train[c[i]].values
    for j in range(i+1, len(c)):
        if np.array_equal(v, df_train[c[j]].values):
            remove.append(c[j])

df_train.drop(remove, axis=1, inplace=True)
df_test.drop(remove, axis=1, inplace=True)

================================================================

# remove constant columns
remove = []
for col in df_train.columns:
    if df_train[col].std() == 0:
        remove.append(col)
================================================================

def fix_nationality(nat):
    for value in nat:
        if value == -999999:
            return 2
        else:
            return value

df_train['var3'] = df_train[['var3']].apply(fix_nationality, axis=1)


'''
# Out:
# '\nADDITIONAL FUNCTIONS FOR FEATURE ENGINEERING\n==============================================================\nimport pickle\nto_save = {\n    "sum_of_0":df_train[\'sum_of_0\']\n}\npickle.dump(to_save, open(\'my_features.pickle\',\'a\'))\n===============================================================\n#NAME: ADD SUM OF 0\'S\n# select on the features, leaving out the \'TARGET\' feature\n\n\nfeatures = [f for f in df_train.columns if f != \'TARGET\' and f!=\'ID\' ]\n\ndef calculate_zeros(cols):\n    sum_array = [] \n    for value in cols:\n        if value == 0:\n            sum_array.append(value)\n    return len(sum_array)\n\ndf_train[\'sum_of_0\'] = df_train[features].apply(calculate_zeros, axis=1)\n\n===============================================================\n\n# remove duplicated columns\nremove = []\nc = df_train.columns\nfor i in range(len(c)-1):\n    v = df_train[c[i]].values\n    for j in range(i+1, len(c)):\n        if np.array_equal(v, df_train[c[j]].values):\n            remove.append(c[j])\n\ndf_train.drop(remove, axis=1, inplace=True)\ndf_test.drop(remove, axis=1, inplace=True)\n\n================================================================\n\n# remove constant columns\nremove = []\nfor col in df_train.columns:\n    if df_train[col].std() == 0:\n        remove.append(col)\n================================================================\n\ndef fix_nationality(nat):\n    for value in nat:\n        if value == -999999:\n            return 2\n        else:\n            return value\n\ndf_train[\'var3\'] = df_train[[\'var3\']].apply(fix_nationality, axis=1)\n\n\n'
